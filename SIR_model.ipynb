# %% [markdown]
# ## What is SIR model ?
# 総人口Nは次の3つのいずれかに分類される.
# - Susceptible : 未感染者
# - Infected : 感染者
# - Recovered : 免疫保持者および死亡者
#
# 各パラメータおよび常微分方程式については [SIRモデルのwiki](https://ja.wikipedia.org/wiki/SIR%E3%83%A2%E3%83%87%E3%83%AB "link")
# を参照.

# %%
from matplotlib import pyplot
import seaborn as sns
import random
import time

# %%
# %matplotlib

N = 300000 # population
I = I0 = 1 # init infected
S = S0 = N-I0 # init susceptible
R = R0 = 0 # init recoverd
beta = 2.5e-6
gamma = 1/14
period = 90 # period 1 = day 1

Slist=[]
Ilist=[]
Rlist=[]
#print("day : 0"+"\nSusceptible :"+str(S)+",Infected :"+str(I)+",Recovered :"+str(R)+"\n"+"-"*30)
plt.figure(facecolor='white')
for i in range(period):
    # calculate Differential Equation
    dS = -beta*S*I
    dI = beta*S*I-(gamma*I)
    dR = gamma*I
    
    S+=dS
    I+=dI
    R+=dR
   
    # errorcheck
    if S<0:
        S=0
    elif S>N:
        S=N
    if I<0:
        I=0
    elif I>N:
        I=N
    if R<0:
        R=0
    elif R>N:
        R=N
    
    # add list
    Slist.append(S)
    Ilist.append(I)
    Rlist.append(R)

    # print result
    print("day : "+str(i+1)+"\nSusceptible :"+str(int(S))+",Infected :"+str(int(I))+",Recovered :"+str(int(R))+"\n"+"-"*30)   
    # make graph
    plt.plot(range(i+1),Slist,label="Susceptible")
    plt.plot(range(i+1),Ilist,label="Infected")
    plt.plot(range(i+1),Rlist,label="Recovered")
    plt.text(0, N,"day : "+str(i+1),fontsize=13)
    plt.legend()
    #plt.ylim(0,50)
    plt.draw()
    plt.pause(0.1)
    if i!=period-1:
        plt.clf()
# Out:
# Using matplotlib backend: Qt5Agg
# day : 1
# Susceptible :299998,Infected :1,Recovered :0
# ------------------------------
# day : 2
# Susceptible :299996,Infected :2,Recovered :0
# ------------------------------
# day : 3
# Susceptible :299994,Infected :4,Recovered :0
# ------------------------------
# day : 4
# Susceptible :299991,Infected :7,Recovered :0
# ------------------------------
# day : 5
# Susceptible :299985,Infected :13,Recovered :1
# ------------------------------
# day : 6
# Susceptible :299975,Infected :22,Recovered :2
# ------------------------------
# day : 7
# Susceptible :299958,Infected :37,Recovered :3
# ------------------------------
# day : 8
# Susceptible :299930,Infected :63,Recovered :6
# ------------------------------
# day : 9
# Susceptible :299883,Infected :105,Recovered :11
# ------------------------------
# day : 10
# Susceptible :299803,Infected :177,Recovered :18
# ------------------------------
# day : 11
# Susceptible :299670,Infected :297,Recovered :31
# ------------------------------
# day : 12
# Susceptible :299447,Infected :499,Recovered :52
# ------------------------------
# day : 13
# Susceptible :299073,Infected :838,Recovered :88
# ------------------------------
# day : 14
# Susceptible :298446,Infected :1404,Recovered :148
# ------------------------------
# day : 15
# Susceptible :297398,Infected :2352,Recovered :248
# ------------------------------
# day : 16
# Susceptible :295649,Infected :3934,Recovered :416
# ------------------------------
# day : 17
# Susceptible :292741,Infected :6561,Recovered :697
# ------------------------------
# day : 18
# Susceptible :287939,Infected :10894,Recovered :1166
# ------------------------------
# day : 19
# Susceptible :280097,Infected :17958,Recovered :1944
# ------------------------------
# day : 20
# Susceptible :267522,Infected :29250,Recovered :3227
# ------------------------------
# day : 21
# Susceptible :247958,Infected :46724,Recovered :5316
# ------------------------------
# day : 22
# Susceptible :218994,Infected :72351,Recovered :8653
# ------------------------------
# day : 23
# Susceptible :179382,Infected :106795,Recovered :13821
# ------------------------------
# day : 24
# Susceptible :131489,Infected :147060,Recovered :21450
# ------------------------------
# day : 25
# Susceptible :83147,Infected :184897,Recovered :31954
# ------------------------------
# day : 26
# Susceptible :44713,Infected :210125,Recovered :45161
# ------------------------------
# day : 27
# Susceptible :21224,Infected :218604,Recovered :60170
# ------------------------------
# day : 28
# Susceptible :9625,Infected :214589,Recovered :75785
# ------------------------------
# day : 29
# Susceptible :4461,Infected :204425,Recovered :91112
# ------------------------------
# day : 30
# Susceptible :2181,Infected :192103,Recovered :105714
# ------------------------------
# day : 31
# Susceptible :1133,Infected :179429,Recovered :119436
# ------------------------------
# day : 32
# Susceptible :625,Infected :167121,Recovered :132252
# ------------------------------
# day : 33
# Susceptible :363,Infected :155445,Recovered :144190
# ------------------------------
# day : 34
# Susceptible :222,Infected :144484,Recovered :155293
# ------------------------------
# day : 35
# Susceptible :142,Infected :134244,Recovered :165613
# ------------------------------
# day : 36
# Susceptible :94,Infected :124703,Recovered :175202
# ------------------------------
# day : 37
# Susceptible :64,Infected :115825,Recovered :184109
# ------------------------------
# day : 38
# Susceptible :46,Infected :107570,Recovered :192383
# ------------------------------
# day : 39
# Susceptible :33,Infected :99899,Recovered :200066
# ------------------------------
# day : 40
# Susceptible :25,Infected :92772,Recovered :207202
# ------------------------------
# day : 41
# Susceptible :19,Infected :86151,Recovered :213829
# ------------------------------
# day : 42
# Susceptible :15,Infected :80002,Recovered :219982
# ------------------------------
# day : 43
# Susceptible :12,Infected :74290,Recovered :225697
# ------------------------------
# day : 44
# Susceptible :9,Infected :68986,Recovered :231003
# ------------------------------
# day : 45
# Susceptible :8,Infected :64060,Recovered :235931
# ------------------------------
# day : 46
# Susceptible :6,Infected :59486,Recovered :240506
# ------------------------------
# day : 47
# Susceptible :5,Infected :55238,Recovered :244755
# ------------------------------
# day : 48
# Susceptible :5,Infected :51293,Recovered :248701
# ------------------------------
# day : 49
# Susceptible :4,Infected :47630,Recovered :252365
# ------------------------------
# day : 50
# Susceptible :3,Infected :44228,Recovered :255767
# ------------------------------
# day : 51
# Susceptible :3,Infected :41069,Recovered :258926
# ------------------------------
# day : 52
# Susceptible :3,Infected :38136,Recovered :261860
# ------------------------------
# day : 53
# Susceptible :2,Infected :35412,Recovered :264584
# ------------------------------
# day : 54
# Susceptible :2,Infected :32883,Recovered :267113
# ------------------------------
# day : 55
# Susceptible :2,Infected :30535,Recovered :269462
# ------------------------------
# day : 56
# Susceptible :2,Infected :28354,Recovered :271643
# ------------------------------
# day : 57
# Susceptible :2,Infected :26328,Recovered :273669
# ------------------------------
# day : 58
# Susceptible :1,Infected :24448,Recovered :275549
# ------------------------------
# day : 59
# Susceptible :1,Infected :22702,Recovered :277295
# ------------------------------
# day : 60
# Susceptible :1,Infected :21080,Recovered :278917
# ------------------------------
# day : 61
# Susceptible :1,Infected :19575,Recovered :280423
# ------------------------------
# day : 62
# Susceptible :1,Infected :18176,Recovered :281821
# ------------------------------
# day : 63
# Susceptible :1,Infected :16878,Recovered :283119
# ------------------------------
# day : 64
# Susceptible :1,Infected :15673,Recovered :284325
# ------------------------------
# day : 65
# Susceptible :1,Infected :14553,Recovered :285445
# ------------------------------
# day : 66
# Susceptible :1,Infected :13514,Recovered :286484
# ------------------------------
# day : 67
# Susceptible :1,Infected :12548,Recovered :287449
# ------------------------------
# day : 68
# Susceptible :1,Infected :11652,Recovered :288346
# ------------------------------
# day : 69
# Susceptible :1,Infected :10820,Recovered :289178
# ------------------------------
# day : 70
# Susceptible :1,Infected :10047,Recovered :289951
# ------------------------------
# day : 71
# Susceptible :1,Infected :9329,Recovered :290669
# ------------------------------
# day : 72
# Susceptible :1,Infected :8663,Recovered :291335
# ------------------------------
# day : 73
# Susceptible :1,Infected :8044,Recovered :291954
# ------------------------------
# day : 74
# Susceptible :1,Infected :7470,Recovered :292528
# ------------------------------
# day : 75
# Susceptible :1,Infected :6936,Recovered :293062
# ------------------------------
# day : 76
# Susceptible :0,Infected :6441,Recovered :293557
# ------------------------------
# day : 77
# Susceptible :0,Infected :5980,Recovered :294018
# ------------------------------
# day : 78
# Susceptible :0,Infected :5553,Recovered :294445
# ------------------------------
# day : 79
# Susceptible :0,Infected :5157,Recovered :294841
# ------------------------------
# day : 80
# Susceptible :0,Infected :4788,Recovered :295210
# ------------------------------
# day : 81
# Susceptible :0,Infected :4446,Recovered :295552
# ------------------------------
# day : 82
# Susceptible :0,Infected :4129,Recovered :295870
# ------------------------------
# day : 83
# Susceptible :0,Infected :3834,Recovered :296164
# ------------------------------
# day : 84
# Susceptible :0,Infected :3560,Recovered :296438
# ------------------------------
# day : 85
# Susceptible :0,Infected :3306,Recovered :296693
# ------------------------------
# day : 86
# Susceptible :0,Infected :3069,Recovered :296929
# ------------------------------
# day : 87
# Susceptible :0,Infected :2850,Recovered :297148
# ------------------------------
# day : 88
# Susceptible :0,Infected :2646,Recovered :297352
# ------------------------------
# day : 89
# Susceptible :0,Infected :2457,Recovered :297541
# ------------------------------
# day : 90
# Susceptible :0,Infected :2282,Recovered :297716
# ------------------------------

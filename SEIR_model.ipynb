# %% [markdown]
# ## What is SEIR model ?
# 総人口Nは次の4つのいずれかに分類される.
# - Susceptible : 未感染者
# - Exposed : 感染しているが発症していない者
# - Infected : 感染かつ発症している者
# - Recovered : 免疫保持者および死亡者
#
# 各パラメータおよび常微分方程式については [SEIRモデルのwiki](https://ja.wikipedia.org/wiki/SEIR%E3%83%A2%E3%83%87%E3%83%AB "link")
# を参照.

# %%
from matplotlib import pyplot
import seaborn as sns
import random
import time

# %%
# %matplotlib

N = 300000 # population
I = I0 = 1 # init infected
S = S0 = N-I0 # init susceptible
E = E0 = 0 # init exposed
R = R0 = 0 # init recoverd

m = 1e-7
a = 1/9
b = 1e-6
g = 1/14
period = 200 # period 1 = day 1

Slist=[]
Elist=[]
Ilist=[]
Rlist=[]
#print("day : 0"+"\nSusceptible :"+str(S)+",Infected :"+str(I)+",Recovered :"+str(R)+"\n"+"-"*30)
plt.figure(facecolor='white')
for i in range(period):
    # calculate Differential Equation
    dS = m*(N-S)-b*S*I
    dE = b*S*I-(m+a)*E
    dI = a*E-(m+g)*I
    dR = g*I-m*R
    
    S+=dS
    E+=dE
    I+=dI
    R+=dR
   
    # errorcheck
    if S<0:
        S=0
    elif S>N:
        S=N
    if E<0:
        E=0
    elif E>N:
        E=N
    if I<0:
        I=0
    elif I>N:
        I=N
    if R<0:
        R=0
    elif R>N:
        R=N
    
    # add list
    Slist.append(S)
    Elist.append(E)
    Ilist.append(I)
    Rlist.append(R)

    # print result
    print("day : "+str(i+1)+"\nSusceptible :"+str(int(S))+",Exposed :"+str(int(E))+",Infected :"+str(int(I))+",Recovered :"+str(int(R)))
    print("\n感染者数 : "+str(int(E+I)))
    print("-"*30)
    # make graph
    plt.plot(range(i+1),Slist,label="Susceptible")
    plt.plot(range(i+1),Elist,label="Exposed")
    plt.plot(range(i+1),Ilist,label="Infected")
    plt.plot(range(i+1),Rlist,label="Recovered")
    plt.text(0, N,"day : "+str(i+1),fontsize=13)
    plt.text(0, N-20000,"感染者数 : "+str(int(E+I)),fontsize=13)
    plt.legend()
    #plt.ylim(0,I+100)
    plt.draw()
    plt.pause(0.05)
    if i!=period-1:
        plt.clf()
# Out:
# Using matplotlib backend: Qt5Agg
# day : 1
# Susceptible :299998,Exposed :0,Infected :0,Recovered :0
#
# 感染者数 : 1
# ------------------------------
# day : 2
# Susceptible :299998,Exposed :0,Infected :0,Recovered :0
#
# 感染者数 : 1
# ------------------------------
# day : 3
# Susceptible :299998,Exposed :0,Infected :0,Recovered :0
#
# 感染者数 : 1
# ------------------------------
# day : 4
# Susceptible :299997,Exposed :0,Infected :0,Recovered :0
#
# 感染者数 : 1
# ------------------------------
# day : 5
# Susceptible :299997,Exposed :1,Infected :0,Recovered :0
#
# 感染者数 : 2
# ------------------------------
# day : 6
# Susceptible :299997,Exposed :1,Infected :1,Recovered :0
#
# 感染者数 : 2
# ------------------------------
# day : 7
# Susceptible :299997,Exposed :1,Infected :1,Recovered :0
#
# 感染者数 : 2
# ------------------------------
# day : 8
# Susceptible :299996,Exposed :1,Infected :1,Recovered :0
#
# 感染者数 : 2
# ------------------------------
# day : 9
# Susceptible :299996,Exposed :1,Infected :1,Recovered :0
#
# 感染者数 : 3
# ------------------------------
# day : 10
# Susceptible :299995,Exposed :1,Infected :1,Recovered :0
#
# 感染者数 : 3
# ------------------------------
# day : 11
# Susceptible :299995,Exposed :2,Infected :1,Recovered :0
#
# 感染者数 : 3
# ------------------------------
# day : 12
# Susceptible :299995,Exposed :2,Infected :1,Recovered :0
#
# 感染者数 : 3
# ------------------------------
# day : 13
# Susceptible :299994,Exposed :2,Infected :1,Recovered :1
#
# 感染者数 : 4
# ------------------------------
# day : 14
# Susceptible :299994,Exposed :2,Infected :1,Recovered :1
#
# 感染者数 : 4
# ------------------------------
# day : 15
# Susceptible :299993,Exposed :3,Infected :2,Recovered :1
#
# 感染者数 : 5
# ------------------------------
# day : 16
# Susceptible :299992,Exposed :3,Infected :2,Recovered :1
#
# 感染者数 : 5
# ------------------------------
# day : 17
# Susceptible :299992,Exposed :3,Infected :2,Recovered :1
#
# 感染者数 : 6
# ------------------------------
# day : 18
# Susceptible :299991,Exposed :4,Infected :2,Recovered :1
#
# 感染者数 : 6
# ------------------------------
# day : 19
# Susceptible :299990,Exposed :4,Infected :2,Recovered :1
#
# 感染者数 : 7
# ------------------------------
# day : 20
# Susceptible :299989,Exposed :4,Infected :3,Recovered :2
#
# 感染者数 : 8
# ------------------------------
# day : 21
# Susceptible :299988,Exposed :5,Infected :3,Recovered :2
#
# 感染者数 : 8
# ------------------------------
# day : 22
# Susceptible :299987,Exposed :5,Infected :3,Recovered :2
#
# 感染者数 : 9
# ------------------------------
# day : 23
# Susceptible :299986,Exposed :6,Infected :4,Recovered :2
#
# 感染者数 : 10
# ------------------------------
# day : 24
# Susceptible :299985,Exposed :6,Infected :4,Recovered :3
#
# 感染者数 : 11
# ------------------------------
# day : 25
# Susceptible :299983,Exposed :7,Infected :5,Recovered :3
#
# 感染者数 : 12
# ------------------------------
# day : 26
# Susceptible :299982,Exposed :8,Infected :5,Recovered :3
#
# 感染者数 : 13
# ------------------------------
# day : 27
# Susceptible :299980,Exposed :8,Infected :6,Recovered :4
#
# 感染者数 : 14
# ------------------------------
# day : 28
# Susceptible :299978,Exposed :9,Infected :6,Recovered :4
#
# 感染者数 : 16
# ------------------------------
# day : 29
# Susceptible :299976,Exposed :10,Infected :7,Recovered :5
#
# 感染者数 : 17
# ------------------------------
# day : 30
# Susceptible :299974,Exposed :11,Infected :7,Recovered :5
#
# 感染者数 : 19
# ------------------------------
# day : 31
# Susceptible :299972,Exposed :12,Infected :8,Recovered :6
#
# 感染者数 : 21
# ------------------------------
# day : 32
# Susceptible :299969,Exposed :13,Infected :9,Recovered :6
#
# 感染者数 : 23
# ------------------------------
# day : 33
# Susceptible :299967,Exposed :15,Infected :10,Recovered :7
#
# 感染者数 : 25
# ------------------------------
# day : 34
# Susceptible :299964,Exposed :16,Infected :11,Recovered :8
#
# 感染者数 : 27
# ------------------------------
# day : 35
# Susceptible :299960,Exposed :17,Infected :12,Recovered :9
#
# 感染者数 : 30
# ------------------------------
# day : 36
# Susceptible :299957,Exposed :19,Infected :13,Recovered :9
#
# 感染者数 : 32
# ------------------------------
# day : 37
# Susceptible :299953,Exposed :21,Infected :14,Recovered :10
#
# 感染者数 : 36
# ------------------------------
# day : 38
# Susceptible :299948,Exposed :23,Infected :15,Recovered :11
#
# 感染者数 : 39
# ------------------------------
# day : 39
# Susceptible :299943,Exposed :25,Infected :17,Recovered :13
#
# 感染者数 : 42
# ------------------------------
# day : 40
# Susceptible :299938,Exposed :27,Infected :18,Recovered :14
#
# 感染者数 : 46
# ------------------------------
# day : 41
# Susceptible :299932,Exposed :30,Infected :20,Recovered :15
#
# 感染者数 : 51
# ------------------------------
# day : 42
# Susceptible :299926,Exposed :33,Infected :22,Recovered :17
#
# 感染者数 : 56
# ------------------------------
# day : 43
# Susceptible :299919,Exposed :36,Infected :24,Recovered :18
#
# 感染者数 : 61
# ------------------------------
# day : 44
# Susceptible :299912,Exposed :39,Infected :27,Recovered :20
#
# 感染者数 : 66
# ------------------------------
# day : 45
# Susceptible :299904,Exposed :43,Infected :29,Recovered :22
#
# 感染者数 : 73
# ------------------------------
# day : 46
# Susceptible :299895,Exposed :47,Infected :32,Recovered :24
#
# 感染者数 : 79
# ------------------------------
# day : 47
# Susceptible :299885,Exposed :51,Infected :35,Recovered :26
#
# 感染者数 : 87
# ------------------------------
# day : 48
# Susceptible :299875,Exposed :56,Infected :38,Recovered :29
#
# 感染者数 : 95
# ------------------------------
# day : 49
# Susceptible :299863,Exposed :61,Infected :42,Recovered :32
#
# 感染者数 : 104
# ------------------------------
# day : 50
# Susceptible :299851,Exposed :67,Infected :45,Recovered :35
#
# 感染者数 : 113
# ------------------------------
# day : 51
# Susceptible :299837,Exposed :73,Infected :50,Recovered :38
#
# 感染者数 : 124
# ------------------------------
# day : 52
# Susceptible :299822,Exposed :80,Infected :54,Recovered :42
#
# 感染者数 : 135
# ------------------------------
# day : 53
# Susceptible :299805,Exposed :88,Infected :59,Recovered :45
#
# 感染者数 : 148
# ------------------------------
# day : 54
# Susceptible :299787,Exposed :96,Infected :65,Recovered :50
#
# 感染者数 : 161
# ------------------------------
# day : 55
# Susceptible :299768,Exposed :105,Infected :71,Recovered :54
#
# 感染者数 : 176
# ------------------------------
# day : 56
# Susceptible :299746,Exposed :114,Infected :78,Recovered :60
#
# 感染者数 : 192
# ------------------------------
# day : 57
# Susceptible :299723,Exposed :125,Infected :85,Recovered :65
#
# 感染者数 : 210
# ------------------------------
# day : 58
# Susceptible :299698,Exposed :137,Infected :93,Recovered :71
#
# 感染者数 : 230
# ------------------------------
# day : 59
# Susceptible :299670,Exposed :149,Infected :101,Recovered :78
#
# 感染者数 : 251
# ------------------------------
# day : 60
# Susceptible :299639,Exposed :163,Infected :111,Recovered :85
#
# 感染者数 : 274
# ------------------------------
# day : 61
# Susceptible :299606,Exposed :178,Infected :121,Recovered :93
#
# 感染者数 : 300
# ------------------------------
# day : 62
# Susceptible :299570,Exposed :195,Infected :132,Recovered :102
#
# 感染者数 : 327
# ------------------------------
# day : 63
# Susceptible :299530,Exposed :213,Infected :144,Recovered :111
#
# 感染者数 : 357
# ------------------------------
# day : 64
# Susceptible :299487,Exposed :232,Infected :158,Recovered :122
#
# 感染者数 : 390
# ------------------------------
# day : 65
# Susceptible :299439,Exposed :254,Infected :172,Recovered :133
#
# 感染者数 : 427
# ------------------------------
# day : 66
# Susceptible :299387,Exposed :277,Infected :188,Recovered :145
#
# 感染者数 : 466
# ------------------------------
# day : 67
# Susceptible :299331,Exposed :303,Infected :205,Recovered :159
#
# 感染者数 : 509
# ------------------------------
# day : 68
# Susceptible :299269,Exposed :331,Infected :224,Recovered :173
#
# 感染者数 : 556
# ------------------------------
# day : 69
# Susceptible :299202,Exposed :361,Infected :245,Recovered :189
#
# 感染者数 : 607
# ------------------------------
# day : 70
# Susceptible :299128,Exposed :395,Infected :268,Recovered :207
#
# 感染者数 : 663
# ------------------------------
# day : 71
# Susceptible :299048,Exposed :431,Infected :293,Recovered :226
#
# 感染者数 : 724
# ------------------------------
# day : 72
# Susceptible :298961,Exposed :471,Infected :320,Recovered :247
#
# 感染者数 : 791
# ------------------------------
# day : 73
# Susceptible :298865,Exposed :514,Infected :349,Recovered :270
#
# 感染者数 : 864
# ------------------------------
# day : 74
# Susceptible :298760,Exposed :561,Infected :381,Recovered :295
#
# 感染者数 : 943
# ------------------------------
# day : 75
# Susceptible :298646,Exposed :613,Infected :417,Recovered :322
#
# 感染者数 : 1030
# ------------------------------
# day : 76
# Susceptible :298522,Exposed :669,Infected :455,Recovered :352
#
# 感染者数 : 1125
# ------------------------------
# day : 77
# Susceptible :298386,Exposed :731,Infected :497,Recovered :384
#
# 感染者数 : 1228
# ------------------------------
# day : 78
# Susceptible :298237,Exposed :798,Infected :543,Recovered :420
#
# 感染者数 : 1341
# ------------------------------
# day : 79
# Susceptible :298075,Exposed :871,Infected :593,Recovered :459
#
# 感染者数 : 1464
# ------------------------------
# day : 80
# Susceptible :297899,Exposed :951,Infected :647,Recovered :501
#
# 感染者数 : 1599
# ------------------------------
# day : 81
# Susceptible :297706,Exposed :1038,Infected :707,Recovered :547
#
# 感染者数 : 1745
# ------------------------------
# day : 82
# Susceptible :297495,Exposed :1133,Infected :771,Recovered :598
#
# 感染者数 : 1905
# ------------------------------
# day : 83
# Susceptible :297266,Exposed :1237,Infected :842,Recovered :653
#
# 感染者数 : 2080
# ------------------------------
# day : 84
# Susceptible :297015,Exposed :1350,Infected :920,Recovered :713
#
# 感染者数 : 2270
# ------------------------------
# day : 85
# Susceptible :296742,Exposed :1473,Infected :1004,Recovered :779
#
# 感染者数 : 2478
# ------------------------------
# day : 86
# Susceptible :296444,Exposed :1608,Infected :1096,Recovered :851
#
# 感染者数 : 2704
# ------------------------------
# day : 87
# Susceptible :296119,Exposed :1754,Infected :1196,Recovered :929
#
# 感染者数 : 2951
# ------------------------------
# day : 88
# Susceptible :295764,Exposed :1913,Infected :1306,Recovered :1015
#
# 感染者数 : 3220
# ------------------------------
# day : 89
# Susceptible :295378,Exposed :2087,Infected :1425,Recovered :1108
#
# 感染者数 : 3513
# ------------------------------
# day : 90
# Susceptible :294957,Exposed :2276,Infected :1555,Recovered :1210
#
# 感染者数 : 3832
# ------------------------------
# day : 91
# Susceptible :294498,Exposed :2482,Infected :1697,Recovered :1321
#
# 感染者数 : 4180
# ------------------------------
# day : 92
# Susceptible :293998,Exposed :2706,Infected :1852,Recovered :1442
#
# 感染者数 : 4558
# ------------------------------
# day : 93
# Susceptible :293454,Exposed :2950,Infected :2020,Recovered :1574
#
# 感染者数 : 4971
# ------------------------------
# day : 94
# Susceptible :292861,Exposed :3215,Infected :2204,Recovered :1719
#
# 感染者数 : 5419
# ------------------------------
# day : 95
# Susceptible :292215,Exposed :3503,Infected :2403,Recovered :1876
#
# 感染者数 : 5907
# ------------------------------
# day : 96
# Susceptible :291513,Exposed :3817,Infected :2621,Recovered :2048
#
# 感染者数 : 6438
# ------------------------------
# day : 97
# Susceptible :290748,Exposed :4157,Infected :2858,Recovered :2235
#
# 感染者数 : 7015
# ------------------------------
# day : 98
# Susceptible :289917,Exposed :4526,Infected :3116,Recovered :2439
#
# 感染者数 : 7642
# ------------------------------
# day : 99
# Susceptible :289014,Exposed :4926,Infected :3396,Recovered :2662
#
# 感染者数 : 8323
# ------------------------------
# day : 100
# Susceptible :288032,Exposed :5361,Infected :3701,Recovered :2904
#
# 感染者数 : 9062
# ------------------------------
# day : 101
# Susceptible :286966,Exposed :5831,Infected :4032,Recovered :3169
#
# 感染者数 : 9864
# ------------------------------
# day : 102
# Susceptible :285809,Exposed :6340,Infected :4392,Recovered :3457
#
# 感染者数 : 10733
# ------------------------------
# day : 103
# Susceptible :284553,Exposed :6891,Infected :4783,Recovered :3771
#
# 感染者数 : 11674
# ------------------------------
# day : 104
# Susceptible :283192,Exposed :7487,Infected :5207,Recovered :4112
#
# 感染者数 : 12694
# ------------------------------
# day : 105
# Susceptible :281718,Exposed :8129,Infected :5667,Recovered :4484
#
# 感染者数 : 13797
# ------------------------------
# day : 106
# Susceptible :280121,Exposed :8823,Infected :6165,Recovered :4889
#
# 感染者数 : 14988
# ------------------------------
# day : 107
# Susceptible :278394,Exposed :9569,Infected :6705,Recovered :5329
#
# 感染者数 : 16275
# ------------------------------
# day : 108
# Susceptible :276527,Exposed :10373,Infected :7290,Recovered :5808
#
# 感染者数 : 17663
# ------------------------------
# day : 109
# Susceptible :274511,Exposed :11236,Infected :7921,Recovered :6329
#
# 感染者数 : 19158
# ------------------------------
# day : 110
# Susceptible :272336,Exposed :12162,Infected :8604,Recovered :6895
#
# 感染者数 : 20767
# ------------------------------
# day : 111
# Susceptible :269993,Exposed :13154,Infected :9341,Recovered :7510
#
# 感染者数 : 22496
# ------------------------------
# day : 112
# Susceptible :267471,Exposed :14215,Infected :10135,Recovered :8177
#
# 感染者数 : 24351
# ------------------------------
# day : 113
# Susceptible :264760,Exposed :15346,Infected :10991,Recovered :8901
#
# 感染者数 : 26338
# ------------------------------
# day : 114
# Susceptible :261850,Exposed :16551,Infected :11911,Recovered :9686
#
# 感染者数 : 28463
# ------------------------------
# day : 115
# Susceptible :258731,Exposed :17831,Infected :12899,Recovered :10537
#
# 感染者数 : 30731
# ------------------------------
# day : 116
# Susceptible :255393,Exposed :19187,Infected :13959,Recovered :11458
#
# 感染者数 : 33147
# ------------------------------
# day : 117
# Susceptible :251828,Exposed :20621,Infected :15094,Recovered :12455
#
# 感染者数 : 35715
# ------------------------------
# day : 118
# Susceptible :248027,Exposed :22131,Infected :16307,Recovered :13533
#
# 感染者数 : 38438
# ------------------------------
# day : 119
# Susceptible :243982,Exposed :23716,Infected :17601,Recovered :14698
#
# 感染者数 : 41318
# ------------------------------
# day : 120
# Susceptible :239688,Exposed :25376,Infected :18979,Recovered :15956
#
# 感染者数 : 44355
# ------------------------------
# day : 121
# Susceptible :235138,Exposed :27105,Infected :20443,Recovered :17311
#
# 感染者数 : 47549
# ------------------------------
# day : 122
# Susceptible :230331,Exposed :28901,Infected :21995,Recovered :18772
#
# 感染者数 : 50896
# ------------------------------
# day : 123
# Susceptible :225265,Exposed :30756,Infected :23635,Recovered :20343
#
# 感染者数 : 54391
# ------------------------------
# day : 124
# Susceptible :219941,Exposed :32662,Infected :25364,Recovered :22031
#
# 感染者数 : 58027
# ------------------------------
# day : 125
# Susceptible :214362,Exposed :34612,Infected :27181,Recovered :23843
#
# 感染者数 : 61794
# ------------------------------
# day : 126
# Susceptible :208535,Exposed :36593,Infected :29086,Recovered :25784
#
# 感染者数 : 65679
# ------------------------------
# day : 127
# Susceptible :202470,Exposed :38592,Infected :31074,Recovered :27862
#
# 感染者数 : 69667
# ------------------------------
# day : 128
# Susceptible :196178,Exposed :40596,Infected :33142,Recovered :30081
#
# 感染者数 : 73739
# ------------------------------
# day : 129
# Susceptible :189676,Exposed :42587,Infected :35286,Recovered :32449
#
# 感染者数 : 77873
# ------------------------------
# day : 130
# Susceptible :182983,Exposed :44548,Infected :37497,Recovered :34969
#
# 感染者数 : 82046
# ------------------------------
# day : 131
# Susceptible :176122,Exposed :46460,Infected :39769,Recovered :37648
#
# 感染者数 : 86229
# ------------------------------
# day : 132
# Susceptible :169118,Exposed :48302,Infected :42090,Recovered :40488
#
# 感染者数 : 90393
# ------------------------------
# day : 133
# Susceptible :161999,Exposed :50053,Infected :44451,Recovered :43495
#
# 感染者数 : 94504
# ------------------------------
# day : 134
# Susceptible :154798,Exposed :51693,Infected :46837,Recovered :46670
#
# 感染者数 : 98530
# ------------------------------
# day : 135
# Susceptible :147548,Exposed :53199,Infected :49235,Recovered :50015
#
# 感染者数 : 102435
# ------------------------------
# day : 136
# Susceptible :140283,Exposed :54553,Infected :51630,Recovered :53532
#
# 感染者数 : 106183
# ------------------------------
# day : 137
# Susceptible :133040,Exposed :55734,Infected :54003,Recovered :57220
#
# 感染者数 : 109738
# ------------------------------
# day : 138
# Susceptible :125856,Exposed :56726,Infected :56339,Recovered :61077
#
# 感染者数 : 113065
# ------------------------------
# day : 139
# Susceptible :118765,Exposed :57514,Infected :58617,Recovered :65102
#
# 感染者数 : 116132
# ------------------------------
# day : 140
# Susceptible :111803,Exposed :58085,Infected :60821,Recovered :69289
#
# 感染者数 : 118907
# ------------------------------
# day : 141
# Susceptible :105003,Exposed :58431,Infected :62930,Recovered :73633
#
# 感染者数 : 121362
# ------------------------------
# day : 142
# Susceptible :98395,Exposed :58547,Infected :64928,Recovered :78128
#
# 感染者数 : 123475
# ------------------------------
# day : 143
# Susceptible :92007,Exposed :58430,Infected :66795,Recovered :82766
#
# 感染者数 : 125226
# ------------------------------
# day : 144
# Susceptible :85861,Exposed :58084,Infected :68516,Recovered :87537
#
# 感染者数 : 126601
# ------------------------------
# day : 145
# Susceptible :79978,Exposed :57513,Infected :70076,Recovered :92431
#
# 感染者数 : 127590
# ------------------------------
# day : 146
# Susceptible :74373,Exposed :56727,Infected :71461,Recovered :97436
#
# 感染者数 : 128189
# ------------------------------
# day : 147
# Susceptible :69059,Exposed :55739,Infected :72660,Recovered :102541
#
# 感染者数 : 128399
# ------------------------------
# day : 148
# Susceptible :64041,Exposed :54563,Infected :73663,Recovered :107731
#
# 感染者数 : 128227
# ------------------------------
# day : 149
# Susceptible :59323,Exposed :53218,Infected :74464,Recovered :112992
#
# 感染者数 : 127683
# ------------------------------
# day : 150
# Susceptible :54906,Exposed :51723,Infected :75058,Recovered :118311
#
# 感染者数 : 126781
# ------------------------------
# day : 151
# Susceptible :50785,Exposed :50097,Infected :75444,Recovered :123673
#
# 感染者数 : 125541
# ------------------------------
# day : 152
# Susceptible :46953,Exposed :48362,Infected :75621,Recovered :129062
#
# 感染者数 : 123984
# ------------------------------
# day : 153
# Susceptible :43402,Exposed :46539,Infected :75593,Recovered :134463
#
# 感染者数 : 122133
# ------------------------------
# day : 154
# Susceptible :40122,Exposed :44649,Infected :75365,Recovered :139863
#
# 感染者数 : 120014
# ------------------------------
# day : 155
# Susceptible :37098,Exposed :42712,Infected :74943,Recovered :145246
#
# 感染者数 : 117655
# ------------------------------
# day : 156
# Susceptible :34317,Exposed :40746,Infected :74335,Recovered :150599
#
# 感染者数 : 115082
# ------------------------------
# day : 157
# Susceptible :31766,Exposed :38770,Infected :73553,Recovered :155909
#
# 感染者数 : 112323
# ------------------------------
# day : 158
# Susceptible :29430,Exposed :36799,Infected :72607,Recovered :161162
#
# 感染者数 : 109406
# ------------------------------
# day : 159
# Susceptible :27293,Exposed :34847,Infected :71510,Recovered :166349
#
# 感染者数 : 106357
# ------------------------------
# day : 160
# Susceptible :25341,Exposed :32927,Infected :70274,Recovered :171457
#
# 感染者数 : 103201
# ------------------------------
# day : 161
# Susceptible :23560,Exposed :31049,Infected :68913,Recovered :176476
#
# 感染者数 : 99962
# ------------------------------
# day : 162
# Susceptible :21937,Exposed :29223,Infected :67440,Recovered :181398
#
# 感染者数 : 96663
# ------------------------------
# day : 163
# Susceptible :20457,Exposed :27455,Infected :65870,Recovered :186216
#
# 感染者数 : 93325
# ------------------------------
# day : 164
# Susceptible :19110,Exposed :25752,Infected :64216,Recovered :190921
#
# 感染者数 : 89968
# ------------------------------
# day : 165
# Susceptible :17883,Exposed :24118,Infected :62490,Recovered :195507
#
# 感染者数 : 86608
# ------------------------------
# day : 166
# Susceptible :16765,Exposed :22555,Infected :60706,Recovered :199971
#
# 感染者数 : 83262
# ------------------------------
# day : 167
# Susceptible :15747,Exposed :21067,Infected :58876,Recovered :204307
#
# 感染者数 : 79944
# ------------------------------
# day : 168
# Susceptible :14820,Exposed :19653,Infected :57012,Recovered :208513
#
# 感染者数 : 76666
# ------------------------------
# day : 169
# Susceptible :13975,Exposed :18315,Infected :55123,Recovered :212585
#
# 感染者数 : 73438
# ------------------------------
# day : 170
# Susceptible :13205,Exposed :17050,Infected :53221,Recovered :216522
#
# 感染者数 : 70271
# ------------------------------
# day : 171
# Susceptible :12502,Exposed :15858,Infected :51314,Recovered :220324
#
# 感染者数 : 67172
# ------------------------------
# day : 172
# Susceptible :11861,Exposed :14738,Infected :49410,Recovered :223989
#
# 感染者数 : 64149
# ------------------------------
# day : 173
# Susceptible :11275,Exposed :13686,Infected :47519,Recovered :227518
#
# 感染者数 : 61205
# ------------------------------
# day : 174
# Susceptible :10739,Exposed :12701,Infected :45645,Recovered :230913
#
# 感染者数 : 58347
# ------------------------------
# day : 175
# Susceptible :10249,Exposed :11780,Infected :43796,Recovered :234173
#
# 感染者数 : 55577
# ------------------------------
# day : 176
# Susceptible :9800,Exposed :10920,Infected :41977,Recovered :237301
#
# 感染者数 : 52897
# ------------------------------
# day : 177
# Susceptible :9388,Exposed :10118,Infected :40192,Recovered :240300
#
# 感染者数 : 50310
# ------------------------------
# day : 178
# Susceptible :9011,Exposed :9371,Infected :38445,Recovered :243171
#
# 感染者数 : 47817
# ------------------------------
# day : 179
# Susceptible :8665,Exposed :8676,Infected :36740,Recovered :245917
#
# 感染者数 : 45417
# ------------------------------
# day : 180
# Susceptible :8346,Exposed :8031,Infected :35080,Recovered :248541
#
# 感染者数 : 43111
# ------------------------------
# day : 181
# Susceptible :8054,Exposed :7431,Infected :33467,Recovered :251047
#
# 感染者数 : 40898
# ------------------------------
# day : 182
# Susceptible :7784,Exposed :6875,Infected :31902,Recovered :253437
#
# 感染者数 : 38777
# ------------------------------
# day : 183
# Susceptible :7536,Exposed :6359,Infected :30387,Recovered :255716
#
# 感染者数 : 36747
# ------------------------------
# day : 184
# Susceptible :7307,Exposed :5882,Infected :28923,Recovered :257886
#
# 感染者数 : 34805
# ------------------------------
# day : 185
# Susceptible :7095,Exposed :5439,Infected :27511,Recovered :259952
#
# 感染者数 : 32951
# ------------------------------
# day : 186
# Susceptible :6900,Exposed :5030,Infected :26150,Recovered :261917
#
# 感染者数 : 31181
# ------------------------------
# day : 187
# Susceptible :6720,Exposed :4652,Infected :24841,Recovered :263785
#
# 感染者数 : 29493
# ------------------------------
# day : 188
# Susceptible :6553,Exposed :4302,Infected :23584,Recovered :265560
#
# 感染者数 : 27886
# ------------------------------
# day : 189
# Susceptible :6398,Exposed :3978,Infected :22377,Recovered :267244
#
# 感染者数 : 26356
# ------------------------------
# day : 190
# Susceptible :6255,Exposed :3679,Infected :21221,Recovered :268843
#
# 感染者数 : 24901
# ------------------------------
# day : 191
# Susceptible :6122,Exposed :3403,Infected :20114,Recovered :270358
#
# 感染者数 : 23518
# ------------------------------
# day : 192
# Susceptible :5999,Exposed :3148,Infected :19055,Recovered :271795
#
# 感染者数 : 22204
# ------------------------------
# day : 193
# Susceptible :5885,Exposed :2913,Infected :18044,Recovered :273156
#
# 感染者数 : 20957
# ------------------------------
# day : 194
# Susceptible :5779,Exposed :2695,Infected :17079,Recovered :274445
#
# 感染者数 : 19775
# ------------------------------
# day : 195
# Susceptible :5680,Exposed :2494,Infected :16158,Recovered :275665
#
# 感染者数 : 18653
# ------------------------------
# day : 196
# Susceptible :5588,Exposed :2309,Infected :15281,Recovered :276819
#
# 感染者数 : 17591
# ------------------------------
# day : 197
# Susceptible :5503,Exposed :2138,Infected :14446,Recovered :277911
#
# 感染者数 : 16585
# ------------------------------
# day : 198
# Susceptible :5424,Exposed :1980,Infected :13652,Recovered :278943
#
# 感染者数 : 15632
# ------------------------------
# day : 199
# Susceptible :5350,Exposed :1834,Infected :12897,Recovered :279918
#
# 感染者数 : 14731
# ------------------------------
# day : 200
# Susceptible :5281,Exposed :1699,Infected :12179,Recovered :280839
#
# 感染者数 : 13879
# ------------------------------

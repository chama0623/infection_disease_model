# %% [markdown]
# ## What is SEIR model ?
# 総人口Nは次の4つのいずれかに分類される.
# - Susceptible : 未感染者
# - Exposed : 感染しているが発症していない者
# - Infected : 感染かつ発症している者
# - Recovered : 免疫保持者および死亡者
#
# 各パラメータおよび常微分方程式については [SEIRモデルのwiki](https://ja.wikipedia.org/wiki/SEIR%E3%83%A2%E3%83%87%E3%83%AB "link")
# を参照.

# %%
from matplotlib import pyplot
import seaborn as sns
import random
import time

# %%
# %matplotlib

N = 1.256e8 # population
I = I0 = 1 # init infected
S = S0 = N-I0 # init susceptible
E = E0 = 0 # init exposed
R = R0 = 0 # init recoverd

m = 1e-10
a = 1/9
b = 4.54e-9
g = 1/14
period = 365 # period 1 = day 1

Slist=[]
Elist=[]
Ilist=[]
Rlist=[]

called=0
#print("day : 0"+"\nSusceptible :"+str(S)+",Infected :"+str(I)+",Recovered :"+str(R)+"\n"+"-"*30)
plt.figure(facecolor='white')
for i in range(period):
    # calculate Differential Equation
    dS = m*(N-S)-b*S*I
    dE = b*S*I-(m+a)*E
    dI = a*E-(m+g)*I
    dR = g*I-m*R
    
    S+=dS
    E+=dE
    I+=dI
    R+=dR
   
    # errorcheck
    if S<0:
        S=0
    elif S>N:
        S=N
    if E<0:
        E=0
    elif E>N:
        E=N
    if I<0:
        I=0
    elif I>N:
        I=N
    if R<0:
        R=0
    elif R>N:
        R=N
    
    # add list
    Slist.append(S)
    Elist.append(E)
    Ilist.append(I)
    Rlist.append(R)

    # print result
    print("day : "+str(i+1)+"\nSusceptible :"+str(int(S))+",Exposed :"+str(int(E))+",Infected :"+str(int(I))+",Recovered :"+str(int(R)))
    print("\n感染者数 : "+str(int(E+I)))
    print("-"*30)
    # make graph
    plt.plot(range(i+1),Slist,label="Susceptible")
    plt.plot(range(i+1),Elist,label="Exposed")
    plt.plot(range(i+1),Ilist,label="Infected")
    plt.plot(range(i+1),Rlist,label="Recovered")
    plt.text(0, N,"day : "+str(i+1),fontsize=13)
    plt.text(0, N-0.1e8,"感染者数 : "+str(int(E+I)),fontsize=13)
    if I > 78000:
        if called==0:
            bed_end=i
            called=1
            xlist=[bed_end,bed_end]
            ylist=[0,N]
        plt.plot(xlist,ylist,color='black',zorder=2)
    else:
        if called==1:
            plt.plot(xlist,ylist,color='black',zorder=2)
            
    plt.legend()
    #plt.ylim(0,I+100)
    plt.draw()
    plt.pause(0.05)
    if i!=period-1:
        plt.clf()
# Out:
# Using matplotlib backend: Qt5Agg
# day : 1
# Susceptible :125599998,Exposed :0,Infected :0,Recovered :0
#
# 感染者数 : 1
# ------------------------------
# day : 2
# Susceptible :125599997,Exposed :1,Infected :0,Recovered :0
#
# 感染者数 : 1
# ------------------------------
# day : 3
# Susceptible :125599997,Exposed :1,Infected :0,Recovered :0
#
# 感染者数 : 2
# ------------------------------
# day : 4
# Susceptible :125599996,Exposed :1,Infected :1,Recovered :0
#
# 感染者数 : 2
# ------------------------------
# day : 5
# Susceptible :125599996,Exposed :2,Infected :1,Recovered :0
#
# 感染者数 : 3
# ------------------------------
# day : 6
# Susceptible :125599995,Exposed :2,Infected :1,Recovered :0
#
# 感染者数 : 4
# ------------------------------
# day : 7
# Susceptible :125599994,Exposed :3,Infected :1,Recovered :0
#
# 感染者数 : 4
# ------------------------------
# day : 8
# Susceptible :125599993,Exposed :3,Infected :1,Recovered :0
#
# 感染者数 : 5
# ------------------------------
# day : 9
# Susceptible :125599992,Exposed :4,Infected :2,Recovered :0
#
# 感染者数 : 6
# ------------------------------
# day : 10
# Susceptible :125599991,Exposed :5,Infected :2,Recovered :0
#
# 感染者数 : 7
# ------------------------------
# day : 11
# Susceptible :125599990,Exposed :5,Infected :2,Recovered :1
#
# 感染者数 : 8
# ------------------------------
# day : 12
# Susceptible :125599988,Exposed :6,Infected :3,Recovered :1
#
# 感染者数 : 10
# ------------------------------
# day : 13
# Susceptible :125599986,Exposed :7,Infected :3,Recovered :1
#
# 感染者数 : 11
# ------------------------------
# day : 14
# Susceptible :125599984,Exposed :9,Infected :4,Recovered :1
#
# 感染者数 : 13
# ------------------------------
# day : 15
# Susceptible :125599982,Exposed :10,Infected :5,Recovered :2
#
# 感染者数 : 15
# ------------------------------
# day : 16
# Susceptible :125599979,Exposed :12,Infected :5,Recovered :2
#
# 感染者数 : 18
# ------------------------------
# day : 17
# Susceptible :125599975,Exposed :14,Infected :6,Recovered :2
#
# 感染者数 : 21
# ------------------------------
# day : 18
# Susceptible :125599972,Exposed :16,Infected :7,Recovered :3
#
# 感染者数 : 24
# ------------------------------
# day : 19
# Susceptible :125599967,Exposed :19,Infected :9,Recovered :3
#
# 感染者数 : 28
# ------------------------------
# day : 20
# Susceptible :125599962,Exposed :22,Infected :10,Recovered :4
#
# 感染者数 : 33
# ------------------------------
# day : 21
# Susceptible :125599956,Exposed :26,Infected :12,Recovered :5
#
# 感染者数 : 38
# ------------------------------
# day : 22
# Susceptible :125599949,Exposed :30,Infected :14,Recovered :6
#
# 感染者数 : 44
# ------------------------------
# day : 23
# Susceptible :125599940,Exposed :35,Infected :16,Recovered :7
#
# 感染者数 : 51
# ------------------------------
# day : 24
# Susceptible :125599931,Exposed :40,Infected :19,Recovered :8
#
# 感染者数 : 60
# ------------------------------
# day : 25
# Susceptible :125599920,Exposed :47,Infected :22,Recovered :9
#
# 感染者数 : 70
# ------------------------------
# day : 26
# Susceptible :125599907,Exposed :55,Infected :26,Recovered :11
#
# 感染者数 : 81
# ------------------------------
# day : 27
# Susceptible :125599892,Exposed :63,Infected :30,Recovered :13
#
# 感染者数 : 94
# ------------------------------
# day : 28
# Susceptible :125599874,Exposed :74,Infected :35,Recovered :15
#
# 感染者数 : 109
# ------------------------------
# day : 29
# Susceptible :125599854,Exposed :86,Infected :41,Recovered :18
#
# 感染者数 : 127
# ------------------------------
# day : 30
# Susceptible :125599831,Exposed :100,Infected :47,Recovered :21
#
# 感染者数 : 147
# ------------------------------
# day : 31
# Susceptible :125599803,Exposed :116,Infected :55,Recovered :24
#
# 感染者数 : 171
# ------------------------------
# day : 32
# Susceptible :125599772,Exposed :134,Infected :64,Recovered :28
#
# 感染者数 : 199
# ------------------------------
# day : 33
# Susceptible :125599735,Exposed :156,Infected :74,Recovered :33
#
# 感染者数 : 231
# ------------------------------
# day : 34
# Susceptible :125599692,Exposed :181,Infected :86,Recovered :38
#
# 感染者数 : 268
# ------------------------------
# day : 35
# Susceptible :125599643,Exposed :211,Infected :100,Recovered :44
#
# 感染者数 : 312
# ------------------------------
# day : 36
# Susceptible :125599585,Exposed :245,Infected :117,Recovered :51
#
# 感染者数 : 362
# ------------------------------
# day : 37
# Susceptible :125599518,Exposed :284,Infected :136,Recovered :60
#
# 感染者数 : 420
# ------------------------------
# day : 38
# Susceptible :125599441,Exposed :330,Infected :157,Recovered :69
#
# 感染者数 : 488
# ------------------------------
# day : 39
# Susceptible :125599351,Exposed :384,Infected :183,Recovered :81
#
# 感染者数 : 567
# ------------------------------
# day : 40
# Susceptible :125599246,Exposed :446,Infected :213,Recovered :94
#
# 感染者数 : 659
# ------------------------------
# day : 41
# Susceptible :125599125,Exposed :517,Infected :247,Recovered :109
#
# 感染者数 : 765
# ------------------------------
# day : 42
# Susceptible :125598984,Exposed :601,Infected :287,Recovered :127
#
# 感染者数 : 888
# ------------------------------
# day : 43
# Susceptible :125598820,Exposed :698,Infected :333,Recovered :147
#
# 感染者数 : 1031
# ------------------------------
# day : 44
# Susceptible :125598630,Exposed :811,Infected :387,Recovered :171
#
# 感染者数 : 1198
# ------------------------------
# day : 45
# Susceptible :125598409,Exposed :941,Infected :449,Recovered :199
#
# 感染者数 : 1391
# ------------------------------
# day : 46
# Susceptible :125598152,Exposed :1093,Infected :522,Recovered :231
#
# 感染者数 : 1615
# ------------------------------
# day : 47
# Susceptible :125597855,Exposed :1269,Infected :606,Recovered :268
#
# 感染者数 : 1876
# ------------------------------
# day : 48
# Susceptible :125597509,Exposed :1474,Infected :704,Recovered :311
#
# 感染者数 : 2178
# ------------------------------
# day : 49
# Susceptible :125597107,Exposed :1712,Infected :817,Recovered :362
#
# 感染者数 : 2530
# ------------------------------
# day : 50
# Susceptible :125596641,Exposed :1988,Infected :949,Recovered :420
#
# 感染者数 : 2938
# ------------------------------
# day : 51
# Susceptible :125596099,Exposed :2309,Infected :1102,Recovered :488
#
# 感染者数 : 3411
# ------------------------------
# day : 52
# Susceptible :125595470,Exposed :2681,Infected :1280,Recovered :567
#
# 感染者数 : 3961
# ------------------------------
# day : 53
# Susceptible :125594740,Exposed :3113,Infected :1487,Recovered :658
#
# 感染者数 : 4600
# ------------------------------
# day : 54
# Susceptible :125593892,Exposed :3615,Infected :1726,Recovered :764
#
# 感染者数 : 5342
# ------------------------------
# day : 55
# Susceptible :125592908,Exposed :4198,Infected :2005,Recovered :888
#
# 感染者数 : 6203
# ------------------------------
# day : 56
# Susceptible :125591765,Exposed :4875,Infected :2328,Recovered :1031
#
# 感染者数 : 7203
# ------------------------------
# day : 57
# Susceptible :125590437,Exposed :5661,Infected :2703,Recovered :1197
#
# 感染者数 : 8364
# ------------------------------
# day : 58
# Susceptible :125588895,Exposed :6573,Infected :3139,Recovered :1390
#
# 感染者数 : 9713
# ------------------------------
# day : 59
# Susceptible :125587105,Exposed :7633,Infected :3645,Recovered :1615
#
# 感染者数 : 11279
# ------------------------------
# day : 60
# Susceptible :125585026,Exposed :8863,Infected :4233,Recovered :1875
#
# 感染者数 : 13097
# ------------------------------
# day : 61
# Susceptible :125582613,Exposed :10292,Infected :4916,Recovered :2177
#
# 感染者数 : 15208
# ------------------------------
# day : 62
# Susceptible :125579810,Exposed :11952,Infected :5708,Recovered :2529
#
# 感染者数 : 17660
# ------------------------------
# day : 63
# Susceptible :125576555,Exposed :13878,Infected :6628,Recovered :2936
#
# 感染者数 : 20507
# ------------------------------
# day : 64
# Susceptible :125572776,Exposed :16115,Infected :7697,Recovered :3410
#
# 感染者数 : 23813
# ------------------------------
# day : 65
# Susceptible :125568388,Exposed :18713,Infected :8938,Recovered :3960
#
# 感染者数 : 27651
# ------------------------------
# day : 66
# Susceptible :125563292,Exposed :21729,Infected :10379,Recovered :4598
#
# 感染者数 : 32108
# ------------------------------
# day : 67
# Susceptible :125557376,Exposed :25231,Infected :12052,Recovered :5339
#
# 感染者数 : 37283
# ------------------------------
# day : 68
# Susceptible :125550506,Exposed :29298,Infected :13994,Recovered :6200
#
# 感染者数 : 43293
# ------------------------------
# day : 69
# Susceptible :125542529,Exposed :34020,Infected :16250,Recovered :7200
#
# 感染者数 : 50270
# ------------------------------
# day : 70
# Susceptible :125533266,Exposed :39502,Infected :18869,Recovered :8361
#
# 感染者数 : 58371
# ------------------------------
# day : 71
# Susceptible :125522512,Exposed :45867,Infected :21911,Recovered :9709
#
# 感染者数 : 67778
# ------------------------------
# day : 72
# Susceptible :125510026,Exposed :53257,Infected :25442,Recovered :11274
#
# 感染者数 : 78699
# ------------------------------
# day : 73
# Susceptible :125495528,Exposed :61837,Infected :29542,Recovered :13091
#
# 感染者数 : 91379
# ------------------------------
# day : 74
# Susceptible :125478696,Exposed :71798,Infected :34303,Recovered :15201
#
# 感染者数 : 106101
# ------------------------------
# day : 75
# Susceptible :125459155,Exposed :83362,Infected :39830,Recovered :17651
#
# 感染者数 : 123192
# ------------------------------
# day : 76
# Susceptible :125436468,Exposed :96786,Infected :46247,Recovered :20496
#
# 感染者数 : 143034
# ------------------------------
# day : 77
# Susceptible :125410130,Exposed :112370,Infected :53698,Recovered :23800
#
# 感染者数 : 166068
# ------------------------------
# day : 78
# Susceptible :125379557,Exposed :130458,Infected :62348,Recovered :27635
#
# 感染者数 : 192807
# ------------------------------
# day : 79
# Susceptible :125344066,Exposed :151453,Infected :72390,Recovered :32089
#
# 感染者数 : 223843
# ------------------------------
# day : 80
# Susceptible :125302872,Exposed :175819,Infected :84047,Recovered :37260
#
# 感染者数 : 259867
# ------------------------------
# day : 81
# Susceptible :125255059,Exposed :204097,Infected :97580,Recovered :43263
#
# 感染者数 : 301677
# ------------------------------
# day : 82
# Susceptible :125199569,Exposed :236909,Infected :113287,Recovered :50233
#
# 感染者数 : 350196
# ------------------------------
# day : 83
# Susceptible :125135176,Exposed :274979,Infected :131518,Recovered :58325
#
# 感染者数 : 406498
# ------------------------------
# day : 84
# Susceptible :125060458,Exposed :319143,Infected :152677,Recovered :67719
#
# 感染者数 : 471821
# ------------------------------
# day : 85
# Susceptible :124973772,Exposed :370369,Infected :177232,Recovered :78625
#
# 感染者数 : 547602
# ------------------------------
# day : 86
# Susceptible :124873213,Exposed :429776,Infected :205725,Recovered :91284
#
# 感染者数 : 635501
# ------------------------------
# day : 87
# Susceptible :124756582,Exposed :498653,Infected :238783,Recovered :105979
#
# 感染者数 : 737437
# ------------------------------
# day : 88
# Susceptible :124621337,Exposed :578493,Infected :277133,Recovered :123035
#
# 感染者数 : 855627
# ------------------------------
# day : 89
# Susceptible :124464540,Exposed :671013,Infected :321615,Recovered :142830
#
# 感染者数 : 992629
# ------------------------------
# day : 90
# Susceptible :124282805,Exposed :778191,Infected :373200,Recovered :165803
#
# 感染者数 : 1151391
# ------------------------------
# day : 91
# Susceptible :124072229,Exposed :902301,Infected :433008,Recovered :192460
#
# 感染者数 : 1335310
# ------------------------------
# day : 92
# Susceptible :123828320,Exposed :1045954,Infected :502335,Recovered :223389
#
# 感染者数 : 1548289
# ------------------------------
# day : 93
# Susceptible :123545917,Exposed :1212140,Infected :582671,Recovered :259270
#
# 感染者数 : 1794811
# ------------------------------
# day : 94
# Susceptible :123219098,Exposed :1404277,Infected :675734,Recovered :300889
#
# 感染者数 : 2080011
# ------------------------------
# day : 95
# Susceptible :122841082,Exposed :1626262,Infected :783498,Recovered :349156
#
# 感染者数 : 2409760
# ------------------------------
# day : 96
# Susceptible :122404126,Exposed :1882522,Infected :908229,Recovered :405120
#
# 感染者数 : 2790752
# ------------------------------
# day : 97
# Susceptible :121899410,Exposed :2178069,Infected :1052525,Recovered :469994
#
# 感染者数 : 3230595
# ------------------------------
# day : 98
# Susceptible :121316917,Exposed :2518554,Infected :1219352,Recovered :545174
#
# 感染者数 : 3737907
# ------------------------------
# day : 99
# Susceptible :120645324,Exposed :2910308,Infected :1412095,Recovered :632271
#
# 感染者数 : 4322404
# ------------------------------
# day : 100
# Susceptible :119871877,Exposed :3360387,Infected :1634599,Recovered :733135
#
# 感染者数 : 4994987
# ------------------------------
# day : 101
# Susceptible :118982298,Exposed :3876590,Infected :1891218,Recovered :849892
#
# 感染者数 : 5767808
# ------------------------------
# day : 102
# Susceptible :117960700,Exposed :4467455,Infected :2186863,Recovered :984979
#
# 感染者数 : 6654319
# ------------------------------
# day : 103
# Susceptible :116789544,Exposed :5142228,Infected :2527043,Recovered :1141184
#
# 感染者数 : 7669271
# ------------------------------
# day : 104
# Susceptible :115449643,Exposed :5910770,Infected :2917898,Recovered :1321687
#
# 感染者数 : 8828668
# ------------------------------
# day : 105
# Susceptible :113920252,Exposed :6783409,Infected :3366229,Recovered :1530108
#
# 感染者数 : 10149639
# ------------------------------
# day : 106
# Susceptible :112179245,Exposed :7770704,Infected :3879496,Recovered :1770553
#
# 感染者数 : 11650201
# ------------------------------
# day : 107
# Susceptible :110203441,Exposed :8883096,Infected :4465801,Recovered :2047660
#
# 感染者数 : 13348897
# ------------------------------
# day : 108
# Susceptible :107969095,Exposed :10130431,Infected :5133826,Recovered :2366646
#
# 感染者数 : 15264258
# ------------------------------
# day : 109
# Susceptible :105452597,Exposed :11521325,Infected :5892728,Recovered :2733348
#
# 感染者数 : 17414053
# ------------------------------
# day : 110
# Susceptible :102631426,Exposed :13062350,Infected :6751966,Recovered :3154257
#
# 感染者数 : 19814316
# ------------------------------
# day : 111
# Susceptible :99485369,Exposed :14757034,Infected :7721055,Recovered :3636540
#
# 感染者数 : 22478089
# ------------------------------
# day : 112
# Susceptible :95998050,Exposed :16604683,Infected :8809221,Recovered :4188044
#
# 感染者数 : 25413904
# ------------------------------
# day : 113
# Susceptible :92158717,Exposed :18599051,Infected :10024956,Recovered :4817274
#
# 感染者数 : 28624008
# ------------------------------
# day : 114
# Susceptible :87964269,Exposed :20726937,Infected :11375449,Recovered :5533343
#
# 感染者数 : 32102387
# ------------------------------
# day : 115
# Susceptible :83421395,Exposed :22966819,Infected :12865910,Recovered :6345875
#
# 感染者数 : 35832729
# ------------------------------
# day : 116
# Susceptible :78548648,Exposed :25287696,Infected :14498785,Recovered :7264868
#
# 感染者数 : 39786482
# ------------------------------
# day : 117
# Susceptible :73378224,Exposed :27648377,Infected :16272902,Recovered :8300496
#
# 感染者数 : 43921279
# ------------------------------
# day : 118
# Susceptible :67957116,Exposed :29997443,Infected :18182593,Recovered :9462846
#
# 感染者数 : 48180037
# ------------------------------
# day : 119
# Susceptible :62347326,Exposed :32274184,Infected :20216886,Recovered :10761603
#
# 感染者数 : 52491070
# ------------------------------
# day : 120
# Susceptible :56624797,Exposed :34410692,Infected :22358843,Recovered :12205666
#
# 感染者数 : 56769535
# ------------------------------
# day : 121
# Susceptible :50876862,Exposed :36335217,Infected :24585193,Recovered :13802726
#
# 感染者数 : 60920410
# ------------------------------
# day : 122
# Susceptible :45198151,Exposed :37976682,Infected :26866354,Recovered :15558811
#
# 感染者数 : 64843036
# ------------------------------
# day : 123
# Susceptible :39685185,Exposed :39270016,Infected :29166960,Recovered :17477837
#
# 感染者数 : 68436977
# ------------------------------
# day : 124
# Susceptible :34430152,Exposed :40161714,Infected :31446941,Recovered :19561191
#
# 感染者数 : 71608655
# ------------------------------
# day : 125
# Susceptible :29514590,Exposed :40614863,Infected :33663144,Recovered :21807401
#
# 感染者数 : 74278007
# ------------------------------
# day : 126
# Susceptible :25003855,Exposed :40612835,Infected :35771396,Recovered :24211912
#
# 感染者数 : 76384232
# ------------------------------
# day : 127
# Susceptible :20943175,Exposed :40160978,Infected :37728834,Recovered :26767011
#
# 感染者数 : 77889812
# ------------------------------
# day : 128
# Susceptible :17355842,Exposed :39285981,Infected :39496248,Recovered :29461928
#
# 感染者数 : 78782229
# ------------------------------
# day : 129
# Susceptible :14243714,Exposed :38032999,Infected :41040196,Recovered :32283089
#
# 感染者数 : 79073196
# ------------------------------
# day : 130
# Susceptible :11589790,Exposed :36461035,Infected :42334642,Recovered :35214531
#
# 感染者数 : 78795678
# ------------------------------
# day : 131
# Susceptible :9362240,Exposed :34637358,Infected :43361965,Recovered :38238434
#
# 感染者数 : 77999324
# ------------------------------
# day : 132
# Susceptible :7519159,Exposed :32631844,Infected :44113278,Recovered :41335718
#
# 感染者数 : 76745122
# ------------------------------
# day : 133
# Susceptible :6013264,Exposed :30511978,Infected :44588090,Recovered :44486666
#
# 感染者数 : 75100068
# ------------------------------
# day : 134
# Susceptible :4796000,Exposed :28339023,Infected :44793446,Recovered :47671530
#
# 感染者数 : 73132469
# ------------------------------
# day : 135
# Susceptible :3820674,Exposed :26165568,Infected :44742694,Recovered :50871061
#
# 感染者数 : 70908263
# ------------------------------
# day : 136
# Susceptible :3044574,Exposed :24034383,Infected :44454073,Recovered :54066968
#
# 感染者数 : 68488457
# ------------------------------
# day : 137
# Susceptible :2430113,Exposed :21978357,Infected :43949269,Recovered :57242259
#
# 感染者数 : 65927626
# ------------------------------
# day : 138
# Susceptible :1945233,Exposed :20021197,Infected :43252075,Recovered :60381493
#
# 感染者数 : 63273272
# ------------------------------
# day : 139
# Susceptible :1563259,Exposed :18178594,Infected :42387219,Recovered :63470927
#
# 感染者数 : 60565813
# ------------------------------
# day : 140
# Susceptible :1262428,Exposed :16459581,Infected :41379404,Recovered :66498585
#
# 感染者数 : 57838985
# ------------------------------
# day : 141
# Susceptible :1025265,Exposed :14867901,Infected :40252575,Recovered :69454257
#
# 感染者数 : 55120476
# ------------------------------
# day : 142
# Susceptible :837901,Exposed :13403276,Infected :39029380,Recovered :72329441
#
# 感染者数 : 52432656
# ------------------------------
# day : 143
# Susceptible :689431,Exposed :12062494,Infected :37730820,Recovered :75117254
#
# 感染者数 : 49793314
# ------------------------------
# day : 144
# Susceptible :571333,Exposed :10840315,Infected :36376038,Recovered :77812312
#
# 感染者数 : 47216354
# ------------------------------
# day : 145
# Susceptible :476979,Exposed :9730189,Infected :34982229,Recovered :80410601
#
# 感染者数 : 44712419
# ------------------------------
# day : 146
# Susceptible :401225,Exposed :8724811,Infected :33564631,Recovered :82909331
#
# 感染者数 : 42289442
# ------------------------------
# day : 147
# Susceptible :340085,Exposed :7816527,Infected :32136581,Recovered :85306805
#
# 感染者数 : 39953108
# ------------------------------
# day : 148
# Susceptible :290466,Exposed :6997643,Infected :30709614,Recovered :87602275
#
# 感染者数 : 37707257
# ------------------------------
# day : 149
# Susceptible :249969,Exposed :6260624,Infected :29293586,Recovered :89795819
#
# 感染者数 : 35554210
# ------------------------------
# day : 150
# Susceptible :216725,Exposed :5598243,Infected :27896812,Recovered :91888218
#
# 感染者数 : 33495056
# ------------------------------
# day : 151
# Susceptible :189276,Exposed :5003665,Infected :26526209,Recovered :93880847
#
# 感染者数 : 31529875
# ------------------------------
# day : 152
# Susceptible :166482,Exposed :4470496,Infected :25187443,Recovered :95775577
#
# 感染者数 : 29657940
# ------------------------------
# day : 153
# Susceptible :147445,Exposed :3992812,Infected :23885062,Recovered :97574680
#
# 感染者数 : 27877874
# ------------------------------
# day : 154
# Susceptible :131456,Exposed :3565155,Infected :22622632,Recovered :99280756
#
# 感染者数 : 26187787
# ------------------------------
# day : 155
# Susceptible :117954,Exposed :3182528,Infected :21402858,Recovered :100896658
#
# 感染者数 : 24585386
# ------------------------------
# day : 156
# Susceptible :106493,Exposed :2840375,Infected :20227696,Recovered :102425434
#
# 感染者数 : 23068072
# ------------------------------
# day : 157
# Susceptible :96713,Exposed :2534558,Infected :19098458,Recovered :103870269
#
# 感染者数 : 21633016
# ------------------------------
# day : 158
# Susceptible :88327,Exposed :2261326,Infected :18015900,Recovered :105234445
#
# 感染者数 : 20277226
# ------------------------------
# day : 159
# Susceptible :81103,Exposed :2017292,Infected :16980309,Recovered :106521295
#
# 感染者数 : 18997601
# ------------------------------
# day : 160
# Susceptible :74851,Exposed :1799401,Infected :15991573,Recovered :107734174
#
# 感染者数 : 17790974
# ------------------------------
# day : 161
# Susceptible :69416,Exposed :1604901,Infected :15049251,Recovered :108876429
#
# 感染者数 : 16654153
# ------------------------------
# day : 162
# Susceptible :64674,Exposed :1431322,Infected :14152627,Recovered :109951376
#
# 感染者数 : 15583949
# ------------------------------
# day : 163
# Susceptible :60518,Exposed :1276441,Infected :13300761,Recovered :110962278
#
# 感染者数 : 14577203
# ------------------------------
# day : 164
# Susceptible :56864,Exposed :1138269,Infected :12492533,Recovered :111912332
#
# 感染者数 : 13630803
# ------------------------------
# day : 165
# Susceptible :53639,Exposed :1015020,Infected :11726684,Recovered :112804656
#
# 感染者数 : 12741704
# ------------------------------
# day : 166
# Susceptible :50783,Exposed :905095,Infected :11001844,Recovered :113642276
#
# 感染者数 : 11906940
# ------------------------------
# day : 167
# Susceptible :48246,Exposed :807066,Infected :10316564,Recovered :114428122
#
# 感染者数 : 11123630
# ------------------------------
# day : 168
# Susceptible :45987,Exposed :719651,Infected :9669340,Recovered :115165020
#
# 感染者数 : 10388992
# ------------------------------
# day : 169
# Susceptible :43968,Exposed :641709,Infected :9058635,Recovered :115855687
#
# 感染者数 : 9700344
# ------------------------------
# day : 170
# Susceptible :42160,Exposed :572216,Infected :8482890,Recovered :116502732
#
# 感染者数 : 9055107
# ------------------------------
# day : 171
# Susceptible :40536,Exposed :510260,Infected :7940549,Recovered :117108653
#
# 感染者数 : 8450810
# ------------------------------
# day : 172
# Susceptible :39075,Exposed :455026,Infected :7430063,Recovered :117675835
#
# 感染者数 : 7885089
# ------------------------------
# day : 173
# Susceptible :37756,Exposed :405786,Infected :6949902,Recovered :118206554
#
# 感染者数 : 7355688
# ------------------------------
# day : 174
# Susceptible :36565,Exposed :361889,Infected :6498568,Recovered :118702975
#
# 感染者数 : 6860458
# ------------------------------
# day : 175
# Susceptible :35486,Exposed :322758,Infected :6074595,Recovered :119167159
#
# 感染者数 : 6397353
# ------------------------------
# day : 176
# Susceptible :34508,Exposed :287875,Infected :5676557,Recovered :119601058
#
# 感染者数 : 5964432
# ------------------------------
# day : 177
# Susceptible :33618,Exposed :256778,Infected :5303075,Recovered :120006527
#
# 感染者数 : 5559853
# ------------------------------
# day : 178
# Susceptible :32809,Exposed :229057,Infected :4952815,Recovered :120385318
#
# 感染者数 : 5181872
# ------------------------------
# day : 179
# Susceptible :32071,Exposed :204343,Infected :4624493,Recovered :120739090
#
# 感染者数 : 4828837
# ------------------------------
# day : 180
# Susceptible :31398,Exposed :182312,Infected :4316877,Recovered :121069411
#
# 感染者数 : 4499189
# ------------------------------
# day : 181
# Susceptible :30783,Exposed :162670,Infected :4028785,Recovered :121377760
#
# 感染者数 : 4191456
# ------------------------------
# day : 182
# Susceptible :30220,Exposed :145159,Infected :3759089,Recovered :121665530
#
# 感染者数 : 3904249
# ------------------------------
# day : 183
# Susceptible :29704,Exposed :129546,Infected :3506712,Recovered :121934037
#
# 感染者数 : 3636258
# ------------------------------
# day : 184
# Susceptible :29231,Exposed :115625,Infected :3270626,Recovered :122184516
#
# 感染者数 : 3386252
# ------------------------------
# day : 185
# Susceptible :28797,Exposed :103211,Infected :3049857,Recovered :122418132
#
# 感染者数 : 3153069
# ------------------------------
# day : 186
# Susceptible :28398,Exposed :92142,Infected :2843478,Recovered :122635979
#
# 感染者数 : 2935621
# ------------------------------
# day : 187
# Susceptible :28032,Exposed :82271,Infected :2650611,Recovered :122839085
#
# 感染者数 : 2732882
# ------------------------------
# day : 188
# Susceptible :27694,Exposed :73467,Infected :2470423,Recovered :123028414
#
# 感染者数 : 2543890
# ------------------------------
# day : 189
# Susceptible :27384,Exposed :65614,Infected :2302127,Recovered :123204873
#
# 感染者数 : 2367742
# ------------------------------
# day : 190
# Susceptible :27097,Exposed :58610,Infected :2144980,Recovered :123369311
#
# 感染者数 : 2203590
# ------------------------------
# day : 191
# Susceptible :26834,Exposed :52362,Infected :1998279,Recovered :123522523
#
# 感染者数 : 2050641
# ------------------------------
# day : 192
# Susceptible :26590,Exposed :46787,Infected :1861363,Recovered :123665258
#
# 感染者数 : 1908151
# ------------------------------
# day : 193
# Susceptible :26365,Exposed :41813,Infected :1733607,Recovered :123798212
#
# 感染者数 : 1775421
# ------------------------------
# day : 194
# Susceptible :26158,Exposed :37375,Infected :1614424,Recovered :123922041
#
# 感染者数 : 1651799
# ------------------------------
# day : 195
# Susceptible :25966,Exposed :33414,Infected :1503261,Recovered :124037357
#
# 感染者数 : 1536675
# ------------------------------
# day : 196
# Susceptible :25789,Exposed :29878,Infected :1399598,Recovered :124144733
#
# 感染者数 : 1429476
# ------------------------------
# day : 197
# Susceptible :25625,Exposed :26722,Infected :1302946,Recovered :124244704
#
# 感染者数 : 1329669
# ------------------------------
# day : 198
# Susceptible :25474,Exposed :23905,Infected :1212848,Recovered :124337772
#
# 感染者数 : 1236753
# ------------------------------
# day : 199
# Susceptible :25333,Exposed :21389,Infected :1128872,Recovered :124424404
#
# 感染者数 : 1150261
# ------------------------------
# day : 200
# Susceptible :25203,Exposed :19142,Infected :1050615,Recovered :124505038
#
# 感染者数 : 1069757
# ------------------------------
# day : 201
# Susceptible :25083,Exposed :17135,Infected :977698,Recovered :124580082
#
# 感染者数 : 994833
# ------------------------------
# day : 202
# Susceptible :24972,Exposed :15343,Infected :909766,Recovered :124649917
#
# 感染者数 : 925109
# ------------------------------
# day : 203
# Susceptible :24869,Exposed :13741,Infected :846488,Recovered :124714901
#
# 感染者数 : 860229
# ------------------------------
# day : 204
# Susceptible :24773,Exposed :12310,Infected :787551,Recovered :124775364
#
# 感染者数 : 799861
# ------------------------------
# day : 205
# Susceptible :24685,Exposed :11031,Infected :732665,Recovered :124831618
#
# 感染者数 : 743696
# ------------------------------
# day : 206
# Susceptible :24603,Exposed :9887,Infected :681557,Recovered :124883951
#
# 感染者数 : 691445
# ------------------------------
# day : 207
# Susceptible :24526,Exposed :8864,Infected :633973,Recovered :124932634
#
# 感染者数 : 642838
# ------------------------------
# day : 208
# Susceptible :24456,Exposed :7950,Infected :589675,Recovered :124977917
#
# 感染者数 : 597625
# ------------------------------
# day : 209
# Susceptible :24390,Exposed :7132,Infected :548438,Recovered :125020037
#
# 感染者数 : 555571
# ------------------------------
# day : 210
# Susceptible :24330,Exposed :6400,Infected :510057,Recovered :125059211
#
# 感染者数 : 516457
# ------------------------------
# day : 211
# Susceptible :24273,Exposed :5745,Infected :474335,Recovered :125095644
#
# 感染者数 : 480081
# ------------------------------
# day : 212
# Susceptible :24221,Exposed :5159,Infected :441092,Recovered :125129525
#
# 感染者数 : 446252
# ------------------------------
# day : 213
# Susceptible :24173,Exposed :4635,Infected :410159,Recovered :125161032
#
# 感染者数 : 414794
# ------------------------------
# day : 214
# Susceptible :24128,Exposed :4165,Infected :381377,Recovered :125190329
#
# 感染者数 : 385542
# ------------------------------
# day : 215
# Susceptible :24086,Exposed :3744,Infected :354599,Recovered :125217570
#
# 感染者数 : 358343
# ------------------------------
# day : 216
# Susceptible :24047,Exposed :3366,Infected :329686,Recovered :125242899
#
# 感染者数 : 333053
# ------------------------------
# day : 217
# Susceptible :24011,Exposed :3028,Infected :306511,Recovered :125266448
#
# 感染者数 : 309540
# ------------------------------
# day : 218
# Susceptible :23978,Exposed :2725,Infected :284954,Recovered :125288341
#
# 感染者数 : 287680
# ------------------------------
# day : 219
# Susceptible :23947,Exposed :2453,Infected :264903,Recovered :125308695
#
# 感染者数 : 267357
# ------------------------------
# day : 220
# Susceptible :23918,Exposed :2209,Infected :246254,Recovered :125327617
#
# 感染者数 : 248464
# ------------------------------
# day : 221
# Susceptible :23891,Exposed :1991,Infected :228910,Recovered :125345206
#
# 感染者数 : 230901
# ------------------------------
# day : 222
# Susceptible :23866,Exposed :1794,Infected :212780,Recovered :125361557
#
# 感染者数 : 214575
# ------------------------------
# day : 223
# Susceptible :23843,Exposed :1618,Infected :197781,Recovered :125376756
#
# 感染者数 : 199399
# ------------------------------
# day : 224
# Susceptible :23822,Exposed :1459,Infected :183834,Recovered :125390883
#
# 感染者数 : 185294
# ------------------------------
# day : 225
# Susceptible :23802,Exposed :1317,Infected :170865,Recovered :125404014
#
# 感染者数 : 172182
# ------------------------------
# day : 226
# Susceptible :23784,Exposed :1189,Infected :158807,Recovered :125416219
#
# 感染者数 : 159996
# ------------------------------
# day : 227
# Susceptible :23766,Exposed :1074,Infected :147595,Recovered :125427562
#
# 感染者数 : 148670
# ------------------------------
# day : 228
# Susceptible :23751,Exposed :971,Infected :137172,Recovered :125438104
#
# 感染者数 : 138143
# ------------------------------
# day : 229
# Susceptible :23736,Exposed :878,Infected :127482,Recovered :125447903
#
# 感染者数 : 128360
# ------------------------------
# day : 230
# Susceptible :23722,Exposed :794,Infected :118474,Recovered :125457008
#
# 感染者数 : 119268
# ------------------------------
# day : 231
# Susceptible :23709,Exposed :718,Infected :110100,Recovered :125465471
#
# 感染者数 : 110818
# ------------------------------
# day : 232
# Susceptible :23697,Exposed :650,Infected :102315,Recovered :125473335
#
# 感染者数 : 102966
# ------------------------------
# day : 233
# Susceptible :23686,Exposed :589,Infected :95079,Recovered :125480643
#
# 感染者数 : 95669
# ------------------------------
# day : 234
# Susceptible :23676,Exposed :534,Infected :88353,Recovered :125487435
#
# 感染者数 : 88887
# ------------------------------
# day : 235
# Susceptible :23667,Exposed :484,Infected :82102,Recovered :125493746
#
# 感染者数 : 82586
# ------------------------------
# day : 236
# Susceptible :23658,Exposed :439,Infected :76291,Recovered :125499610
#
# 感染者数 : 76730
# ------------------------------
# day : 237
# Susceptible :23650,Exposed :398,Infected :70890,Recovered :125505060
#
# 感染者数 : 71289
# ------------------------------
# day : 238
# Susceptible :23642,Exposed :362,Infected :65871,Recovered :125510123
#
# 感染者数 : 66233
# ------------------------------
# day : 239
# Susceptible :23635,Exposed :328,Infected :61206,Recovered :125514828
#
# 感染者数 : 61535
# ------------------------------
# day : 240
# Susceptible :23629,Exposed :298,Infected :56871,Recovered :125519200
#
# 感染者数 : 57170
# ------------------------------
# day : 241
# Susceptible :23623,Exposed :271,Infected :52842,Recovered :125523262
#
# 感染者数 : 53114
# ------------------------------
# day : 242
# Susceptible :23617,Exposed :247,Infected :49098,Recovered :125527037
#
# 感染者数 : 49345
# ------------------------------
# day : 243
# Susceptible :23612,Exposed :225,Infected :45618,Recovered :125530544
#
# 感染者数 : 45843
# ------------------------------
# day : 244
# Susceptible :23607,Exposed :204,Infected :42385,Recovered :125533802
#
# 感染者数 : 42589
# ------------------------------
# day : 245
# Susceptible :23602,Exposed :186,Infected :39380,Recovered :125536830
#
# 感染者数 : 39567
# ------------------------------
# day : 246
# Susceptible :23598,Exposed :170,Infected :36588,Recovered :125539643
#
# 感染者数 : 36758
# ------------------------------
# day : 247
# Susceptible :23594,Exposed :155,Infected :33993,Recovered :125542256
#
# 感染者数 : 34148
# ------------------------------
# day : 248
# Susceptible :23590,Exposed :141,Infected :31582,Recovered :125544684
#
# 感染者数 : 31724
# ------------------------------
# day : 249
# Susceptible :23587,Exposed :129,Infected :29342,Recovered :125546940
#
# 感染者数 : 29471
# ------------------------------
# day : 250
# Susceptible :23584,Exposed :118,Infected :27261,Recovered :125549036
#
# 感染者数 : 27379
# ------------------------------
# day : 251
# Susceptible :23581,Exposed :107,Infected :25326,Recovered :125550983
#
# 感染者数 : 25434
# ------------------------------
# day : 252
# Susceptible :23578,Exposed :98,Infected :23529,Recovered :125552792
#
# 感染者数 : 23628
# ------------------------------
# day : 253
# Susceptible :23576,Exposed :90,Infected :21860,Recovered :125554473
#
# 感染者数 : 21950
# ------------------------------
# day : 254
# Susceptible :23574,Exposed :82,Infected :20308,Recovered :125556034
#
# 感染者数 : 20391
# ------------------------------
# day : 255
# Susceptible :23571,Exposed :75,Infected :18867,Recovered :125557485
#
# 感染者数 : 18942
# ------------------------------
# day : 256
# Susceptible :23569,Exposed :69,Infected :17527,Recovered :125558833
#
# 感染者数 : 17597
# ------------------------------
# day : 257
# Susceptible :23567,Exposed :63,Infected :16283,Recovered :125560085
#
# 感染者数 : 16346
# ------------------------------
# day : 258
# Susceptible :23566,Exposed :58,Infected :15127,Recovered :125561248
#
# 感染者数 : 15185
# ------------------------------
# day : 259
# Susceptible :23564,Exposed :53,Infected :14053,Recovered :125562328
#
# 感染者数 : 14106
# ------------------------------
# day : 260
# Susceptible :23563,Exposed :48,Infected :13055,Recovered :125563332
#
# 感染者数 : 13104
# ------------------------------
# day : 261
# Susceptible :23561,Exposed :44,Infected :12128,Recovered :125564265
#
# 感染者数 : 12173
# ------------------------------
# day : 262
# Susceptible :23560,Exposed :41,Infected :11267,Recovered :125565131
#
# 感染者数 : 11308
# ------------------------------
# day : 263
# Susceptible :23559,Exposed :37,Infected :10466,Recovered :125565936
#
# 感染者数 : 10504
# ------------------------------
# day : 264
# Susceptible :23558,Exposed :34,Infected :9723,Recovered :125566683
#
# 感染者数 : 9758
# ------------------------------
# day : 265
# Susceptible :23557,Exposed :31,Infected :9032,Recovered :125567378
#
# 感染者数 : 9064
# ------------------------------
# day : 266
# Susceptible :23556,Exposed :29,Infected :8391,Recovered :125568023
#
# 感染者数 : 8420
# ------------------------------
# day : 267
# Susceptible :23555,Exposed :26,Infected :7794,Recovered :125568622
#
# 感染者数 : 7821
# ------------------------------
# day : 268
# Susceptible :23554,Exposed :24,Infected :7241,Recovered :125569179
#
# 感染者数 : 7265
# ------------------------------
# day : 269
# Susceptible :23553,Exposed :22,Infected :6726,Recovered :125569696
#
# 感染者数 : 6749
# ------------------------------
# day : 270
# Susceptible :23553,Exposed :20,Infected :6248,Recovered :125570177
#
# 感染者数 : 6269
# ------------------------------
# day : 271
# Susceptible :23552,Exposed :19,Infected :5804,Recovered :125570623
#
# 感染者数 : 5824
# ------------------------------
# day : 272
# Susceptible :23551,Exposed :17,Infected :5392,Recovered :125571038
#
# 感染者数 : 5410
# ------------------------------
# day : 273
# Susceptible :23551,Exposed :16,Infected :5009,Recovered :125571423
#
# 感染者数 : 5025
# ------------------------------
# day : 274
# Susceptible :23550,Exposed :15,Infected :4653,Recovered :125571781
#
# 感染者数 : 4668
# ------------------------------
# day : 275
# Susceptible :23550,Exposed :13,Infected :4322,Recovered :125572113
#
# 感染者数 : 4336
# ------------------------------
# day : 276
# Susceptible :23549,Exposed :12,Infected :4015,Recovered :125572422
#
# 感染者数 : 4028
# ------------------------------
# day : 277
# Susceptible :23549,Exposed :11,Infected :3729,Recovered :125572708
#
# 感染者数 : 3741
# ------------------------------
# day : 278
# Susceptible :23548,Exposed :10,Infected :3464,Recovered :125572975
#
# 感染者数 : 3475
# ------------------------------
# day : 279
# Susceptible :23548,Exposed :10,Infected :3218,Recovered :125573222
#
# 感染者数 : 3228
# ------------------------------
# day : 280
# Susceptible :23548,Exposed :9,Infected :2989,Recovered :125573452
#
# 感染者数 : 2999
# ------------------------------
# day : 281
# Susceptible :23547,Exposed :8,Infected :2777,Recovered :125573666
#
# 感染者数 : 2785
# ------------------------------
# day : 282
# Susceptible :23547,Exposed :7,Infected :2579,Recovered :125573864
#
# 感染者数 : 2587
# ------------------------------
# day : 283
# Susceptible :23547,Exposed :7,Infected :2396,Recovered :125574048
#
# 感染者数 : 2403
# ------------------------------
# day : 284
# Susceptible :23547,Exposed :6,Infected :2226,Recovered :125574220
#
# 感染者数 : 2232
# ------------------------------
# day : 285
# Susceptible :23546,Exposed :6,Infected :2067,Recovered :125574379
#
# 感染者数 : 2074
# ------------------------------
# day : 286
# Susceptible :23546,Exposed :5,Infected :1920,Recovered :125574526
#
# 感染者数 : 1926
# ------------------------------
# day : 287
# Susceptible :23546,Exposed :5,Infected :1784,Recovered :125574663
#
# 感染者数 : 1789
# ------------------------------
# day : 288
# Susceptible :23546,Exposed :4,Infected :1657,Recovered :125574791
#
# 感染者数 : 1662
# ------------------------------
# day : 289
# Susceptible :23546,Exposed :4,Infected :1539,Recovered :125574909
#
# 感染者数 : 1544
# ------------------------------
# day : 290
# Susceptible :23546,Exposed :4,Infected :1430,Recovered :125575019
#
# 感染者数 : 1434
# ------------------------------
# day : 291
# Susceptible :23545,Exposed :3,Infected :1328,Recovered :125575121
#
# 感染者数 : 1332
# ------------------------------
# day : 292
# Susceptible :23545,Exposed :3,Infected :1233,Recovered :125575216
#
# 感染者数 : 1237
# ------------------------------
# day : 293
# Susceptible :23545,Exposed :3,Infected :1146,Recovered :125575304
#
# 感染者数 : 1149
# ------------------------------
# day : 294
# Susceptible :23545,Exposed :3,Infected :1064,Recovered :125575386
#
# 感染者数 : 1067
# ------------------------------
# day : 295
# Susceptible :23545,Exposed :2,Infected :988,Recovered :125575462
#
# 感染者数 : 991
# ------------------------------
# day : 296
# Susceptible :23545,Exposed :2,Infected :918,Recovered :125575533
#
# 感染者数 : 921
# ------------------------------
# day : 297
# Susceptible :23545,Exposed :2,Infected :853,Recovered :125575598
#
# 感染者数 : 855
# ------------------------------
# day : 298
# Susceptible :23545,Exposed :2,Infected :792,Recovered :125575659
#
# 感染者数 : 794
# ------------------------------
# day : 299
# Susceptible :23545,Exposed :2,Infected :736,Recovered :125575716
#
# 感染者数 : 738
# ------------------------------
# day : 300
# Susceptible :23545,Exposed :1,Infected :683,Recovered :125575769
#
# 感染者数 : 685
# ------------------------------
# day : 301
# Susceptible :23544,Exposed :1,Infected :635,Recovered :125575817
#
# 感染者数 : 637
# ------------------------------
# day : 302
# Susceptible :23544,Exposed :1,Infected :590,Recovered :125575863
#
# 感染者数 : 591
# ------------------------------
# day : 303
# Susceptible :23544,Exposed :1,Infected :548,Recovered :125575905
#
# 感染者数 : 549
# ------------------------------
# day : 304
# Susceptible :23544,Exposed :1,Infected :509,Recovered :125575944
#
# 感染者数 : 510
# ------------------------------
# day : 305
# Susceptible :23544,Exposed :1,Infected :472,Recovered :125575980
#
# 感染者数 : 474
# ------------------------------
# day : 306
# Susceptible :23544,Exposed :1,Infected :439,Recovered :125576014
#
# 感染者数 : 440
# ------------------------------
# day : 307
# Susceptible :23544,Exposed :1,Infected :408,Recovered :125576046
#
# 感染者数 : 409
# ------------------------------
# day : 308
# Susceptible :23544,Exposed :1,Infected :379,Recovered :125576075
#
# 感染者数 : 380
# ------------------------------
# day : 309
# Susceptible :23544,Exposed :0,Infected :352,Recovered :125576102
#
# 感染者数 : 353
# ------------------------------
# day : 310
# Susceptible :23544,Exposed :0,Infected :327,Recovered :125576127
#
# 感染者数 : 327
# ------------------------------
# day : 311
# Susceptible :23544,Exposed :0,Infected :303,Recovered :125576150
#
# 感染者数 : 304
# ------------------------------
# day : 312
# Susceptible :23544,Exposed :0,Infected :282,Recovered :125576172
#
# 感染者数 : 282
# ------------------------------
# day : 313
# Susceptible :23544,Exposed :0,Infected :262,Recovered :125576192
#
# 感染者数 : 262
# ------------------------------
# day : 314
# Susceptible :23544,Exposed :0,Infected :243,Recovered :125576211
#
# 感染者数 : 244
# ------------------------------
# day : 315
# Susceptible :23544,Exposed :0,Infected :226,Recovered :125576228
#
# 感染者数 : 226
# ------------------------------
# day : 316
# Susceptible :23544,Exposed :0,Infected :210,Recovered :125576244
#
# 感染者数 : 210
# ------------------------------
# day : 317
# Susceptible :23544,Exposed :0,Infected :195,Recovered :125576259
#
# 感染者数 : 195
# ------------------------------
# day : 318
# Susceptible :23544,Exposed :0,Infected :181,Recovered :125576273
#
# 感染者数 : 181
# ------------------------------
# day : 319
# Susceptible :23544,Exposed :0,Infected :168,Recovered :125576286
#
# 感染者数 : 168
# ------------------------------
# day : 320
# Susceptible :23544,Exposed :0,Infected :156,Recovered :125576298
#
# 感染者数 : 156
# ------------------------------
# day : 321
# Susceptible :23544,Exposed :0,Infected :145,Recovered :125576309
#
# 感染者数 : 145
# ------------------------------
# day : 322
# Susceptible :23544,Exposed :0,Infected :134,Recovered :125576320
#
# 感染者数 : 135
# ------------------------------
# day : 323
# Susceptible :23544,Exposed :0,Infected :125,Recovered :125576329
#
# 感染者数 : 125
# ------------------------------
# day : 324
# Susceptible :23544,Exposed :0,Infected :116,Recovered :125576338
#
# 感染者数 : 116
# ------------------------------
# day : 325
# Susceptible :23544,Exposed :0,Infected :108,Recovered :125576347
#
# 感染者数 : 108
# ------------------------------
# day : 326
# Susceptible :23544,Exposed :0,Infected :100,Recovered :125576354
#
# 感染者数 : 100
# ------------------------------
# day : 327
# Susceptible :23544,Exposed :0,Infected :93,Recovered :125576361
#
# 感染者数 : 93
# ------------------------------
# day : 328
# Susceptible :23544,Exposed :0,Infected :86,Recovered :125576368
#
# 感染者数 : 86
# ------------------------------
# day : 329
# Susceptible :23544,Exposed :0,Infected :80,Recovered :125576374
#
# 感染者数 : 80
# ------------------------------
# day : 330
# Susceptible :23544,Exposed :0,Infected :74,Recovered :125576380
#
# 感染者数 : 74
# ------------------------------
# day : 331
# Susceptible :23544,Exposed :0,Infected :69,Recovered :125576385
#
# 感染者数 : 69
# ------------------------------
# day : 332
# Susceptible :23544,Exposed :0,Infected :64,Recovered :125576390
#
# 感染者数 : 64
# ------------------------------
# day : 333
# Susceptible :23544,Exposed :0,Infected :59,Recovered :125576395
#
# 感染者数 : 60
# ------------------------------
# day : 334
# Susceptible :23544,Exposed :0,Infected :55,Recovered :125576399
#
# 感染者数 : 55
# ------------------------------
# day : 335
# Susceptible :23544,Exposed :0,Infected :51,Recovered :125576403
#
# 感染者数 : 51
# ------------------------------
# day : 336
# Susceptible :23544,Exposed :0,Infected :48,Recovered :125576407
#
# 感染者数 : 48
# ------------------------------
# day : 337
# Susceptible :23544,Exposed :0,Infected :44,Recovered :125576410
#
# 感染者数 : 44
# ------------------------------
# day : 338
# Susceptible :23544,Exposed :0,Infected :41,Recovered :125576413
#
# 感染者数 : 41
# ------------------------------
# day : 339
# Susceptible :23544,Exposed :0,Infected :38,Recovered :125576416
#
# 感染者数 : 38
# ------------------------------
# day : 340
# Susceptible :23544,Exposed :0,Infected :35,Recovered :125576419
#
# 感染者数 : 35
# ------------------------------
# day : 341
# Susceptible :23544,Exposed :0,Infected :33,Recovered :125576422
#
# 感染者数 : 33
# ------------------------------
# day : 342
# Susceptible :23544,Exposed :0,Infected :30,Recovered :125576424
#
# 感染者数 : 30
# ------------------------------
# day : 343
# Susceptible :23544,Exposed :0,Infected :28,Recovered :125576426
#
# 感染者数 : 28
# ------------------------------
# day : 344
# Susceptible :23544,Exposed :0,Infected :26,Recovered :125576428
#
# 感染者数 : 26
# ------------------------------
# day : 345
# Susceptible :23544,Exposed :0,Infected :24,Recovered :125576430
#
# 感染者数 : 24
# ------------------------------
# day : 346
# Susceptible :23544,Exposed :0,Infected :22,Recovered :125576432
#
# 感染者数 : 23
# ------------------------------
# day : 347
# Susceptible :23544,Exposed :0,Infected :21,Recovered :125576433
#
# 感染者数 : 21
# ------------------------------
# day : 348
# Susceptible :23544,Exposed :0,Infected :19,Recovered :125576435
#
# 感染者数 : 19
# ------------------------------
# day : 349
# Susceptible :23544,Exposed :0,Infected :18,Recovered :125576436
#
# 感染者数 : 18
# ------------------------------
# day : 350
# Susceptible :23544,Exposed :0,Infected :17,Recovered :125576438
#
# 感染者数 : 17
# ------------------------------
# day : 351
# Susceptible :23544,Exposed :0,Infected :15,Recovered :125576439
#
# 感染者数 : 15
# ------------------------------
# day : 352
# Susceptible :23544,Exposed :0,Infected :14,Recovered :125576440
#
# 感染者数 : 14
# ------------------------------
# day : 353
# Susceptible :23544,Exposed :0,Infected :13,Recovered :125576441
#
# 感染者数 : 13
# ------------------------------
# day : 354
# Susceptible :23544,Exposed :0,Infected :12,Recovered :125576442
#
# 感染者数 : 12
# ------------------------------
# day : 355
# Susceptible :23544,Exposed :0,Infected :11,Recovered :125576443
#
# 感染者数 : 11
# ------------------------------
# day : 356
# Susceptible :23544,Exposed :0,Infected :10,Recovered :125576444
#
# 感染者数 : 11
# ------------------------------
# day : 357
# Susceptible :23544,Exposed :0,Infected :10,Recovered :125576445
#
# 感染者数 : 10
# ------------------------------
# day : 358
# Susceptible :23544,Exposed :0,Infected :9,Recovered :125576445
#
# 感染者数 : 9
# ------------------------------
# day : 359
# Susceptible :23544,Exposed :0,Infected :8,Recovered :125576446
#
# 感染者数 : 8
# ------------------------------
# day : 360
# Susceptible :23544,Exposed :0,Infected :8,Recovered :125576447
#
# 感染者数 : 8
# ------------------------------
# day : 361
# Susceptible :23544,Exposed :0,Infected :7,Recovered :125576447
#
# 感染者数 : 7
# ------------------------------
# day : 362
# Susceptible :23544,Exposed :0,Infected :7,Recovered :125576448
#
# 感染者数 : 7
# ------------------------------
# day : 363
# Susceptible :23544,Exposed :0,Infected :6,Recovered :125576448
#
# 感染者数 : 6
# ------------------------------
# day : 364
# Susceptible :23544,Exposed :0,Infected :6,Recovered :125576449
#
# 感染者数 : 6
# ------------------------------
# day : 365
# Susceptible :23544,Exposed :0,Infected :5,Recovered :125576449
#
# 感染者数 : 5
# ------------------------------
